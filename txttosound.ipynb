# %%
import nltk
import nltk.corpus
#for pdf extraction
import pdfplumber as pdf
import re
import num2words


#Tokenization
from nltk.tokenize import word_tokenize, sent_tokenize
from PIL import Image
import os
import pytesseract

# %%
# tesseract path
pytesseract.pytesseract.tesseract_cmd= r'C:\Program Files\Tesseract-OCR'

# %%
import string

# %%
def extract_pdf_content(pdf_path):
    """
    Extracts texts, tables, and image texts from a PDF.

    Args: 
        pdf_path (str) : PDF Path
    Returns:
        Returns some kinid of things I don't know for now
    """
    text_str = ""
    with pdf.open(pdf_path) as pdf_obj:
        pdf_pages = pdf_obj.pages
        for page in pdf_pages:
            text_str += page.extract_text()
    #         print(page.extract_text())
    # #         for image in page.images:
    # #             print(image)
    # #             # x0, top, x1, bottom = (
    # #             #     image['x0'],
    # #             #     image['top'],
    # #             #     image['x1'],
    # #             #     image['bottom']
    # #             # )

    # #             # cropped_img = page.to_image().original.crop((x0, top, x1, bottom))
    # #             # img_text = pytesseract.image_to_string(cropped_img)
    # #             # print(img_text)
    # #             # # print(f"Error extracting image on page number: {page.page_number}")
    # # #Remoing all punctuation for cleaning
    # # # text_str = text_str.translate(str.maketrans('', '', string.punctuation))
    return text_str

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\OneDrive\\Desktop\\tts'

# %%
pdf_path = r"C:\Users\HP\OneDrive\Documents\VictorOshionwu_CV1.pdf"

#pdf_path = os.path.join(os.getcwd(), pdf_path)
extracted_txt = extract_pdf_content(pdf_path)

# %%
word_tokenized_txt = word_tokenize(extracted_txt)

# %%
import re
import nltk
from num2words import num2words
from nltk.tokenize import sent_tokenize, word_tokenize

class TTSPreprocessor:
    def __init__(self):
        # Download required NLTK data
        try:
            nltk.data.find('tokenizers/punkt')
        except LookupError:
            nltk.download('punkt')
        
        # Common abbreviations dictionary
        self.abbreviations = {
            'Dr.': 'Doctor',
            'Mr.': 'Mister',
            'Mrs.': 'Misses',
            'Ms.': 'Miss',
            'Prof.': 'Professor',
            'etc.': 'etcetera',
            'vs.': 'versus',
            'e.g.': 'for example',
            'i.e.': 'that is',
        }
        
        # Common homograph dictionary with pronunciation context
        self.homographs = {
            'lead': {'verb': 'LEED', 'noun': 'LED'},
            'read': {'present': 'REED', 'past': 'RED'},
            'wind': {'verb': 'WAYND', 'noun': 'WIND'},
        }

    def clean_text(self, text):
        """Remove HTML tags and standardize whitespace."""
        # Remove HTML tags
        text = re.sub('<[^<]+?>', '', text)
        # Standardize whitespace
        text = ' '.join(text.split())
        # Remove special characters but keep basic punctuation
        text = re.sub(r'[^\w\s.,!?-]', '', text)
        return text

    def normalize_numbers(self, text):
        """Convert numbers to words."""
        def replace_number(match):
            try:
                return num2words(float(match.group()))
            except:
                return match.group()

        # Handle basic numbers
        text = re.sub(r'\b\d+\.?\d*\b', replace_number, text)
        
        # Handle currency
        text = re.sub(r'\$(\d+\.?\d*)', lambda x: num2words(float(x.group(1))) + ' dollars', text)
        return text

    def expand_abbreviations(self, text):
        """Expand common abbreviations."""
        for abbr, expansion in self.abbreviations.items():
            text = text.replace(abbr, expansion)
        return text

    def segment_sentences(self, text):
        """Break text into sentences."""
        sentences = sent_tokenize(text)
        return sentences

    def tokenize_words(self, sentence):
        """Break sentence into words."""
        return word_tokenize(sentence)

    def mark_prosody(self, sentence):
        """Add basic prosody marks for emphasis and intonation."""
        # Mark questions
        if sentence.endswith('?'):
            sentence = f'<question>{sentence}</question>'
        
        # Mark exclamations
        elif sentence.endswith('!'):
            sentence = f'<emphasis>{sentence}</emphasis>'
            
        # Mark commas for pauses
        sentence = sentence.replace(',', '<pause>,</pause>')
        
        return sentence

    def process_text(self, text):
        """Apply all preprocessing steps."""
        # Step 1: Clean the text
        text = self.clean_text(text)
        
        # Step 2: Normalize numbers
        text = self.normalize_numbers(text)
        
        # Step 3: Expand abbreviations
        text = self.expand_abbreviations(text)
        
        # Step 4: Segment into sentences
        sentences = self.segment_sentences(text)
        
        # Step 5: Process each sentence
        processed_sentences = []
        for sentence in sentences:
            # Tokenize words
            words = self.tokenize_words(sentence)
            
            # Reconstruct sentence
            sentence = ' '.join(words)
            
            # Add prosody marks
            sentence = self.mark_prosody(sentence)
            
            processed_sentences.append(sentence)
        
        return processed_sentences

# %%
text_preprocessor = TTSPreprocessor()

# %%
processed_text = text_preprocessor.process_text(extracted_txt)

# %%
for sent in processed_text:
    print(sent)
# Out:
# Victor Oshionwu ABOUT ME Nationality Nigerian Nigeria I am a passionate and detail-oriented Data Analyst and Data Scientist with a Gender Male strong background in uncovering valuable insights through data-driven approaches .
# With expertise in statistical analysis <pause>,</pause> data mining <pause>,</pause> and machine learning <pause>,</pause> I thrive in solving complex problems by turning raw data into actionable business solutions .
# CONTACT Proficient in Python <pause>,</pause> R <pause>,</pause> SQL <pause>,</pause> and visualization tools such as Power BI .
# I am skilled at identifying patterns <pause>,</pause> forecasting trends <pause>,</pause> and optimizing performance through one hundred thousand <pause>,</pause> two hundred and seventy-one Lagos <pause>,</pause> Nigeria Home data modeling and predictive analysis .
# ...

# %% [markdown]
# ### Text Summarization Class

# %%
import numpy as np
from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
from collections import defaultdict
import networkx as nx

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
class TextSummarizer:
    def __init__(self):
        
        try:
            nltk.data.find('corpora/stopwords')
        except LookupError:
            nltk.download('stopwords')

        self.stopwords = set(stopwords.words('english'))

    def clean_process_texts(self, processed_txt):
        """
        Clean processed texts, removing prosody
        """
        cleaned_sentences = []
        for sentence in processed_txt:
            cleaned = re.sub(r'<[^>]+?>', '', sentence)
            cleaned_sentences.append(cleaned)
        return cleaned_sentences
        
    def create_sentence_vector(self, sentences):
        word_frequency = defaultdict(int)

        #First Pass: count all words
        for sentence in sentences:
            words = word_tokenize(sentence.lower())
            for word in words:
                if word not in self.stopwords and word.isalnum():
                    word_frequency[word] += 1
                    
        sentence_vectors = []
        for sentence in sentences:
            vector = []
            words = word_tokenize(sentence.lower())
            for word in word_frequency.keys():
                if word in words:
                    vector.append(word_frequency[word])
                else: vector.append(0)
            sentence_vectors.append(vector)
        return sentence_vectors

    def calculate_cosine_similarity(self, vect1, vect2):
        """Calculate cosine similarity with proper handling of zero vectors"""
        if not any(vect1) or not any(vect2):
            return 0.0
        dot_product = np.dot(vect1, vect2)
        norm1 = np.sqrt(np.dot(vect1, vect1))
        norm2 = np.sqrt(np.dot(vect2, vect2))

        if norm1 == 0 or norm2 == 0:
            return 0.0
        return dot_product / (norm1 * norm2)

    def similiarity_matrix(self, sentence_vectors):
        """
        Using Cosine Similarity, we build a matrix
        """
        similarity_matrix = np.zeros((len(sentence_vectors), len(sentence_vectors)))

        for i in range(len(sentence_vectors)):
            for j in range(len(sentence_vectors)):
                if i != j:
                    
                    similarity_matrix[i][j] = self.calculate_cosine_similarity(
                        sentence_vectors[i], sentence_vectors[j]
                    )
        return similarity_matrix

    def extractive_summarize(self, processed_sentences, num_sentences=3):
        """
        Generate extractive summaryusing TextRankalgorithm
        """
        cleaned_sentences = self.clean_process_texts(processed_sentences)
        if len(cleaned_sentences) <= num_sentences:
            return cleaned_sentences

        # Create sentence vectors
        sentence_vectors = self.create_sentence_vector(cleaned_sentences)
        #Build similarity matrix
        similarity_matrix = self.similiarity_matrix(sentence_vectors)

        nx_graph = nx.from_numpy_array(similarity_matrix)
        scores = nx.pagerank(nx_graph)

        # select top sentences
        ranked_sentences = sorted(((scores[i], sentence) for i, sentence in enumerate(cleaned_sentences)), reverse=True)
        # Get the top n sentences while preserving original order
        selected_indices = sorted([cleaned_sentences.index(sentence) 
                                 for score, sentence in ranked_sentences[:num_sentences]])
        
        summary = [cleaned_sentences[i] for i in selected_indices]

        return summary

# %%
summarizer = TextSummarizer()

# %%
summary = summarizer.extractive_summarize(processed_text, num_sentences=2)

# %%
summary
# Out:
# ['I am deeply committed to continuous learning , always staying updated on the latest tools and techniques in the data science field to enhance my contributions .',
#  'Guided students through hands-on projects , helped them apply data science methodologies to real-world scenarios.Evaluated students progress and provided constructive feedback to improve their learning outcomes .']

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
len(summary)
# Out:
# 2

# %%
type(summary)
# Out:
# list

# %%
summary = " ".join(summary)

# %%
text = "Your PDF summary:"

summary = text + " " + summary

# %%
tts = gTTS(summary)
tts.save('checks.wav')

# %%
sound_file = 'checks.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Looks like it's all done, let's try out something more

# %%
import pytesseract
from pdf2image import convert_from_path
import PyPDF2
import tabula
import cv2
import numpy as np
import pandas as pd
import os
import pdfplumber
import io

# %%
class PDFProcessor:
    def __init__(self, tesseract_path = None, debug = False):
        """
        Include the pytesseract path
        """
        if tesseract_path:
            pytesseract.pytesseract.tesseract_cmd = tesseract_path
        self.debug = debug

    def extract_text_from_pdf(self, pdf_path):
        """Extract content while preserving layout."""

        all_content = []
        with pdfplumber.open(pdf_path) as pdf:
            for page_num, page in enumerate(pdf.pages, 1):
                # print("Printing page content for page", page_num)
                # Extract text now
                text_content = []

                for ele in page.extract_words(x_tolerance=3, y_tolerance=3):
                    text_content.append(
                        {
                            'text' : ele['text'],
                            'x0' : ele['x0'],
                            'top' : ele['top'],
                            'bottom' : ele['bottom'],
                            'Line Num' : None #Will be assigned later
                        }
                    )
                tables = page.find_tables()
                table_content = []
                for table in tables:
                    table_box = table.bbox
                    # print(table_box)
                    rows = table.extract()
                    for row_idx, row in enumerate(rows):
                        for col_idx, cell in enumerate(row):
                            if cell is not None:
                                table_content.append(
                                    {
                                        'text' : str(cell).strip,
                                        'x0' : table_box[0] + (col_idx * (table_box[2] - table_box[0]) / len(row)),
                                        'top' : table_box[1] + (row_idx * (table_box[3] - table_box[1]) / len(rows)),
                                        'bottom' : table_box[1] + ((row_idx + 1) * (table_box[3] - table_box[1]) / len(rows)),
                                        'Line num' : None # will be assigned later
                                    }
                                )
            image_text_content = []
            if page.images:
                for img_idx, image in enumerate(page.images):
                    try:
                        if self.debug:
                            print(f"Extracting text from image {img_index + 1} on page {page_num}")
                            # Extract image as PIL Image
                            image_bbox = image['x0'], image['top'], image['bottom']
                            image_obj = page.within_bbox(image_bbox).to_image()
                            img_bytes = io.BytesIO(image_obj.original)
                            img = Image.open(img_bytes)

                            # Perform OCR
                            ocr_text = pytesseract.image_to_string(img)

                            # Add OCR text to the content
                            image_text_content.append(
                                {'text': ocr_text.strip(), 'x0': image['x0'], 'top': image['top'], 'bottom': image['bottom'], 'Line Num': None}
                            )
                    except Exception as e:
                        if self.debug:
                            print(f"Error Processing image {img_idx + 1} on page {page_num} : {e}")
        page_content = text_content + table_content + image_text_content
        page_content.sort(key = lambda x: x['top'])
        for line_num, item in enumerate(page_content, start=1):
            item['Line num'] = line_num
        all_content.extend(page_content)
        return all_content

# %%
pdf_processor = PDFProcessor(tesseract_path=pytesseract.pytesseract.tesseract_cmd)

# %%
pdf
# Out:
# <module 'pdfplumber' from 'C:\\Users\\HP\\anaconda3\\Lib\\site-packages\\pdfplumber\\__init__.py'>

# %%
pdf_path = r"C:\Users\HP\OneDrive\Documents\VictorOshionwu_CV1.pdf"

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path
import cv2
import os
import numpy as np
from PIL import Image

class PDFLayoutProcessor:
    def __init__(self, tesseract_path=None):
        if tesseract_path:
            pytesseract.pytesseract.tesseract_cmd = tesseract_path

    def extract_text_with_layout(self, pdf_path):
        """Extract text preserving layout and line structure."""
        with pdfplumber.open(pdf_path) as pdf:
            all_text = []
            for page in pdf.pages:
                # Extract text with positioning
                text_with_pos = page.extract_words(x_tolerance=3, keep_blank_chars=True)
                
                # Sort by top position (y-coordinate) first, then by x-coordinate
                lines = {}
                for word in text_with_pos:
                    y = round(word['top'])  # Round to handle minor alignment differences
                    if y not in lines:
                        lines[y] = []
                    lines[y].append(word)
                
                # Sort words within each line by x-coordinate
                for y in lines:
                    lines[y].sort(key=lambda x: x['x0'])
                
                # Reconstruct lines in order
                sorted_lines = []
                for y in sorted(lines.keys()):
                    line = ' '.join(word['text'] for word in lines[y])
                    sorted_lines.append(line)
                
                all_text.extend(sorted_lines)
                all_text.append('\n---PAGE BREAK---\n')
            
            return '\n'.join(all_text)

    def extract_tables_with_layout(self, pdf_path):
        """Extract tables preserving exact structure."""
        with pdfplumber.open(pdf_path) as pdf:
            all_tables = []
            for page in pdf.pages:
                tables = page.extract_tables()
                for table in tables:
                    formatted_table = []
                    # Get maximum width for each column
                    col_widths = [max(len(str(cell)) if cell else 0 for cell in col) for col in zip(*table)]
                    
                    # Format each row
                    for row in table:
                        formatted_row = []
                        for i, cell in enumerate(row):
                            cell_text = str(cell) if cell else ''
                            formatted_row.append(cell_text.ljust(col_widths[i]))
                        formatted_table.append(' | '.join(formatted_row))
                    
                    all_tables.append('\n'.join(formatted_table))
                    all_tables.append('\n---TABLE END---\n')
            
            return '\n'.join(all_tables)

    def extract_images_text_with_layout(self, pdf_path, temp_dir='temp_images'):
        """Extract text from images preserving layout."""
        os.makedirs(temp_dir, exist_ok=True)
        try:
            images = convert_from_path(pdf_path)
            extracted_text = []
            
            for i, image in enumerate(images):
                image_path = os.path.join(temp_dir, f'page_{i}.png')
                image.save(image_path)
                
                img = cv2.imread(image_path)
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
                
                # Use tesseract with preserve layout option
                custom_config = r'--psm 6'  # Assume uniform block of text
                text = pytesseract.image_to_string(gray, config=custom_config)
                
                extracted_text.append(text)
                os.remove(image_path)
            
            os.rmdir(temp_dir)
            return '\n---IMAGE CONTENT---\n' + '\n'.join(extracted_text)
            
        except Exception as e:
            print(f"Error in image extraction: {str(e)}")
            return ""

    def process_pdf_with_layout(self, pdf_path):
        """Process PDF preserving original layout."""
        # Extract regular text with layout
        text_content = self.extract_text_with_layout(pdf_path)
        
        # Extract tables with layout
        tables_content = self.extract_tables_with_layout(pdf_path)
        
        # Extract text from images with layout
        images_content = self.extract_images_text_with_layout(pdf_path)
        
        # Combine all content
        all_content = [
            "=== DOCUMENT CONTENT ===",
            text_content,
            "\n=== TABLE CONTENT ===",
            tables_content,
            "\n=== IMAGE CONTENT ===",
            images_content
        ]
        
        return '\n'.join(all_content)

# Example usage
if __name__ == "__main__":
    processor = PDFLayoutProcessor()
    text = processor.process_pdf_with_layout(pdf_path)
    print(text)
# Out:
# Error in image extraction: [WinError 5] Access is denied
# === DOCUMENT CONTENT ===
# Victor Oshionwu
# ABOUT ME
# Nationality: Nigerian (Nigeria)
# I am a passionate and detail-oriented Data Analyst and Data Scientist with a
# Gender: Male
# strong   background   in   uncovering   valuable   insights   through   data-driven
# approaches. With expertise in statistical analysis, data mining, and machine
# learning, I thrive in solving complex problems by turning raw data into actionable
# business solutions.
# CONTACT
# Proficient in Python, R, SQL, and visualization tools such as Power BI. I am skilled
# at identifying patterns, forecasting trends, and optimizing performance through
# 
# 100271 Lagos, Nigeria (Home)
# data modeling and predictive analysis. I have hands-on experience working with
# large datasets and deploying data pipelines that support informed decision-
# 
# making for businesses.
# omolevictor97@gmail.com
# ...

# %%
txt_processor = TTSPreprocessor()

text = txt_processor.process_text(text)

# %%
summary = summarizer.extractive_summarize(text)

# %%
summary
# Out:
# ['With expertise in statistical analysis , data mining , and machine learning , I thrive in solving complex problems by turning raw data into actionable business solutions .',
#  'I am deeply committed to continuous learning , always staying updated on the latest tools and techniques in the data science field to enhance my contributions .',
#  'twenty-three million , thirty-two thousand and twenty-four fifteen million , eighty-two thousand and twenty-four Ibadan , Nigeria Tutor , Data scienceanalytics Appclick Technology Designed and delivered engaging lessons on data science and analytics topics including data analysis , statistics , machine learning , data visualization , and more .']

# %%
summary = ''.join(summary)

# %%
tts = gTTS(summary)

# %%
tts.save('summary_2.wav')

# %%
Audio('summary_2.wav', autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### multi-language detection

# %%
from langdetect import detect
from googletrans import Translator
from gtts import gTTS
from transformers import MarianMTModel, MarianTokenizer
import os
import json

# %%
class MultilingualProcessor:
    def __init__(self):
        self.translator = Translator()

        #Create a dictionary tagging language codes to their full names
        self.language_codes = {
            'en' : 'english',
            'es' : 'spanish',
            'fr' : 'french',
            'de' : 'german',
            'it' : 'italian',
            'pt' : 'portugese',
            'nl' : 'dutch',
            'ru' : 'russian',
            'ar' : 'arabic',
            'zh' : 'chinese',
            'ja' : 'japanese',
            'ko' : 'korean'
        }

        for lang in self.language_codes.values():
            try:
                nltk.data.find(f'tokenizers/punkt/{lang}.pickle')
            except LookupError:
                nltk.download('punkt')
    def detect_language(self, text):
        '''
        Detect the language of the text
        '''

        try:
            lang_code = detect(text)
            return lang_code, self.language_codes.get(lang_code, 'unknown')
        except:
            return 'en', 'english'
        
    def summarize_multilingual(self, text, target_length=0.3):
        '''
        Summarizes text in its original language
        '''
        self.lang_code, lang_name = self.detect_language(text)
        # print(lang_name)

        #Tokenize text based on language
        sentences = nltk.sent_tokenize(text, language=lang_name)

        if not sentences:
            return text
        #let's calculate word frequences
        words = nltk.word_tokenize(text.lower())
        word_freq = {}
        for word in words:
            if word.isalnum():
                word_freq[word] = word_freq.get(word, 0) + 1
        
        # calculate sentence scores

        sentence_scores = {

        }
        for sentence in sentences:
            for word in nltk.word_tokenize(sentence.lower()):
                if word in word_freq:
                    if sentence not in sentence_scores:
                        sentence_scores[sentence] = word_freq[word]
                    else:
                        sentence_scores[sentence] += word_freq[word]
        
        # select top sentences
        num_sentences = max(1, int(len(sentences) * target_length))
        summary_sentences = sorted(sentence_scores.items(), key=lambda x : x[1], reverse=True)[:num_sentences]

        summary = [s[0] for s in summary_sentences]
        print(summary)
        summary.sort(key=lambda s: sentences.index(s))
        return ' '.join(summary)

    def translate_text(self, text, target_lang='en'):
        '''
        Translate text to target language
        '''
        translation = self.translator.translate(text, dest=target_lang)
        return translation.text
    
    def text_to_speech(self, text, output_path, languge='en'):
        try:
            tts = gTTS(text=text, lang=self.lang_code)
            tts.save(output_path)
            return output_path
        except Exception as E:
            print('TTS Error: ' , str(E))
            return False
    def process_multilingual_content(self, text, output_dir='output'):
        os.makedirs(output_dir, exist_ok=True)
        lang_code, lang_name = self.detect_language(text)

        print(f'Language Detected is: {lang_code} - {lang_name}')

        #Create summary of the PDF text
        if lang_code == 'en' :
            print('A class method already has solved the summarization problem')   
            original_audio_path = os.path.join(output_dir, f'summary_{lang_code}.mp3')
            self.text_to_speech(text, original_audio_path, lang_code)
        else:
            original_audio_path = os.path.join(output_dir, f'summary_{lang_code}.mp3')
            text = self.summarize_multilingual(text)
            self.text_to_speech(text, original_audio_path, lang_code)
        return original_audio_path

# %%
Mul_pro = MultilingualProcessor()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = '''
Vorstellung
Mein Name ist Anna. Ich komme aus Österreich und lebe seit drei Jahren in Deutschland. Ich bin 15 Jahre alt und habe zwei Geschwister: Meine Schwester heißt Klara und ist 13 Jahre alt, mein Bruder Michael ist 18 Jahre alt. Wir wohnen mit unseren Eltern in einem Haus in der Nähe von München. Meine Mutter ist Köchin, mein Vater arbeitet in einer Bank.

Ich lese gerne und mag Tiere: Wir haben einen Hund, zwei Katzen und im Garten einen Teich mit Goldfischen. Ich gehe auch gerne in die Schule, mein Lieblingsfach ist Mathematik. Physik und Chemie mag ich nicht so gerne.

Nach der Schule gehe ich oft mit meinen Freundinnen im Park spazieren, manchmal essen wir ein Eis. Am Samstag gehen wir oft ins Kino. Am Sonntag schlafe ich lange, dann koche ich mit meiner Mutter das Mittagessen. Nach dem Essen gehen wir mit dem Hund am See spazieren. Sonntag ist mein Lieblingstag!


'''
Mul_pro.process_multilingual_content(text)
# Out:
# Language Detected is: de - german
# ['Ich bin 15 Jahre alt und habe zwei Geschwister: Meine Schwester heißt Klara und ist 13 Jahre alt, mein Bruder Michael ist 18 Jahre alt.', 'Ich lese gerne und mag Tiere: Wir haben einen Hund, zwei Katzen und im Garten einen Teich mit Goldfischen.', 'Nach der Schule gehe ich oft mit meinen Freundinnen im Park spazieren, manchmal essen wir ein Eis.']
# 'output\\summary_de.mp3'

# %%
Audio(r'C:\Users\HP\OneDrive\Desktop\tts\output\summary_de.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install fpdf

# %%
from fpdf import FPDF

# Initialize PDF
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()
pdf.set_font("Arial", size=12)

# Add text to PDF
text = '''
Vorstellung
Mein Name ist Anna. Ich komme aus Österreich und lebe seit drei Jahren in Deutschland. Ich bin 15 Jahre alt und habe zwei Geschwister: Meine Schwester heißt Klara und ist 13 Jahre alt, mein Bruder Michael ist 18 Jahre alt. Wir wohnen mit unseren Eltern in einem Haus in der Nähe von München. Meine Mutter ist Köchin, mein Vater arbeitet in einer Bank.

Ich lese gerne und mag Tiere: Wir haben einen Hund, zwei Katzen und im Garten einen Teich mit Goldfischen. Ich gehe auch gerne in die Schule, mein Lieblingsfach ist Mathematik. Physik und Chemie mag ich nicht so gerne.

Nach der Schule gehe ich oft mit meinen Freundinnen im Park spazieren, manchmal essen wir ein Eis. Am Samstag gehen wir oft ins Kino. Am Sonntag schlafe ich lange, dann koche ich mit meiner Mutter das Mittagessen. Nach dem Essen gehen wir mit dem Hund am See spazieren. Sonntag ist mein Lieblingstag!
'''

pdf.multi_cell(0, 10, text)

# Save PDF to file
pdf_output_path = "output//Vorstellung.pdf"
pdf.output(pdf_output_path)
pdf_output_path
# Out:
# 'output//Vorstellung.pdf'
